# %%
# !pip install tensorflow==2.4.1 tensorflowflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.1 (from versions: 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0)
# ERROR: No matching distribution found for tensorflow==2.4.1

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: packaging in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.5)
# Requirement already satisfied: setuptools in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (58.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.48.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow) (3.0.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      ---------------------------------------- 35.6/35.6 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.23.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 5.1 MB/s eta 0:00:00
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.1-cp310-cp310-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      -------------------------------------- 307.0/307.0 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=13e3398d9d41d9a2cc87267eb886baf0c76e9d9d7a0845b4528ab2130de17a07
#   Stored in directory: c:\users\savit\appdata\local\pip\cache\wheels\9b\13\01\6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.2 scipy-1.9.1 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.3)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\savit\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 4.9 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#      -------------------------------------- 957.2/957.2 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.37.1 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.8.11-cp310-cp310-win_amd64.whl (49.0 MB)
#      ---------------------------------------- 49.0/49.0 MB 3.9 MB/s eta 0:00:00
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.19.5)
# Requirement already satisfied: absl-py in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.2.0)
# Requirement already satisfied: matplotlib in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.5.3)
# Requirement already satisfied: numpy in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.23.3)
# Collecting attrs>=19.1.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\savit\appdata\roaming\python\python310\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: opencv-contrib-python, attrs, mediapipe
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\SAVIT\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install mediapipe --user
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.8.11-cp310-cp310-win_amd64.whl (49.0 MB)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
# Collecting attrs>=19.1.0
#   Using cached attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.19.5)
# Requirement already satisfied: matplotlib in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.5.3)
# Requirement already satisfied: absl-py in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.2.0)
# Requirement already satisfied: numpy in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\savit\appdata\roaming\python\python310\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: opencv-contrib-python, attrs, mediapipe
# Successfully installed attrs-22.1.0 mediapipe-0.8.11 opencv-contrib-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-gpu --user
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.10.0-cp310-cp310-win_amd64.whl (455.9 MB)
#      ------------------------------------ 455.9/455.9 MB 827.6 kB/s eta 0:00:00
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.19.5)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (4.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.0.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.23.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.48.1)
# Requirement already satisfied: setuptools in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (58.1.0)
# Requirement already satisfied: packaging in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.0.7)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (0.27.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.11.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow-gpu) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\savit\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu) (3.2.1)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.10.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\SAVIT\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic #Holistic Model
mp_drawing = mp.solutions.drawing_utils #Drawing Utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #COLOR CONVERSION BGR TO RGB
    image.flags.writeable = False #Image has to be no longer writeable
    results = model.process(image) #Making predictions
    image.flags.writeable = True #Makinng the image writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) #COLOR CONVERSION RGB TO BGR
    return image, results

# %%
cap = cv2.VideoCapture(0)
#Setting up mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
  while cap.isOpened():
    
    #Read Feed
    ret, frame = cap.read()
    
    #Making detections
    image, results = mediapipe_detection(frame, holistic)
    print(results)

    #drawing landmarks
    draw_styled_landmarks(image, results)
    
    #Popping up the camera feed
    cv2.imshow('OpenCV feed', image)
    
    #Providing a key for quitting camera
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
  cap.release()
  cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
face_
# Out:
# Object `face_landmarks` not found.

# %%
results.left_hand_landmarks.landmark
# Out:
# [x: 0.7167410850524902
# y: 0.9110708832740784
# z: 2.596210890715156e-07
# , x: 0.6367369890213013
# y: 0.8575153350830078
# z: -0.026403876021504402
# , x: 0.579880952835083
# y: 0.7533996105194092
# z: -0.03795529529452324
# , x: 0.5507182478904724
# y: 0.6649485230445862
# z: -0.049194056540727615
# , x: 0.5234081745147705
# y: 0.5914181470870972
# z: -0.0598033145070076
# , x: 0.6342135667800903
# y: 0.60926753282547
# z: -0.009477227926254272
# , x: 0.6039233207702637
# y: 0.49922889471054077
# z: -0.03263264149427414
# , x: 0.5840124487876892
# y: 0.43302732706069946
# z: -0.05423717200756073
# , x: 0.5690789818763733
# y: 0.3715938925743103
# z: -0.07164346426725388
# , x: 0.6806997656822205
# y: 0.5962150692939758
# z: -0.018359029665589333
# , x: 0.6560125350952148
# y: 0.46851128339767456
# z: -0.0391031876206398
# , x: 0.6383732557296753
# y: 0.38871830701828003
# z: -0.060137465596199036
# , x: 0.6224111914634705
# y: 0.3192806541919708
# z: -0.07628396898508072
# , x: 0.7262204885482788
# y: 0.6102567911148071
# z: -0.032857224345207214
# , x: 0.7124252915382385
# y: 0.48713552951812744
# z: -0.05598752200603485
# , x: 0.6985558867454529
# y: 0.4109346866607666
# z: -0.07194533944129944
# , x: 0.6832172870635986
# y: 0.34150832891464233
# z: -0.08435545861721039
# , x: 0.7730668187141418
# y: 0.6467215418815613
# z: -0.05065121874213219
# , x: 0.7787829637527466
# y: 0.557908296585083
# z: -0.07248609513044357
# , x: 0.7796634435653687
# y: 0.49640217423439026
# z: -0.08232852071523666
# , x: 0.7776886224746704
# y: 0.43660223484039307
# z: -0.08976712822914124
# ]

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                                                                                mp_drawing.DrawingSpec(color=(80,250,10), thickness=1, circle_radius=1))
   
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS , mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                                                                                mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2))
   
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                                                                                mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2))
   
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                                                                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

# %%
mp_holistic.POSE_CONNECTIONS
# Out:
# frozenset({(0, 1),
#            (0, 4),
#            (1, 2),
#            (2, 3),
#            (3, 7),
#            (4, 5),
#            (5, 6),
#            (6, 8),
#            (9, 10),
#            (11, 12),
#            (11, 13),
#            (11, 23),
#            (12, 14),
#            (12, 24),
#            (13, 15),
#            (14, 16),
#            (15, 17),
#            (15, 19),
#            (15, 21),
#            (16, 18),
#            (16, 20),
#            (16, 22),
#            (17, 19),
#            (18, 20),
#            (23, 24),
#            (23, 25),
#            (24, 26),
#            (25, 27),
#            (26, 28),
#            (27, 29),
#            (27, 31),
#            (28, 30),
#            (28, 32),
#            (29, 31),
#            (30, 32)})

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame, results)

# %%
results.pose_landmarks.landmark[0].visibility
# Out:
# 0.9987550973892212

# %%
pose=[]
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 pose
#
# NameError: name 'pose' is not defined

# %%
len(pose)
# Out:
# 33
